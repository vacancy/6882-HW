# %% [markdown]
# # 6.882 HW 2.1 Starter Code [Solutions]
#
# See the problem set handout for instructions and deliverables.
#
# See HW1.1 Starter Code for dependency installation instructions.

# %%
# Install dependencies (run this once ever 12 hours)
# !pip install --upgrade git+https://github.com/tomsilver/pddlgym # Install most recent PDDLGym (must be from source!)
# !pip install tabulate
# Out:
# Collecting git+https://github.com/tomsilver/pddlgym
#   Cloning https://github.com/tomsilver/pddlgym to /private/var/folders/2y/1l8njzj51qd7b7jnwzz5v2bm0000gn/T/pip-req-build-ps_xibhz
# Requirement already satisfied, skipping upgrade: matplotlib in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pddlgym==0.0.2) (3.3.1)
# Requirement already satisfied, skipping upgrade: pillow in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pddlgym==0.0.2) (7.2.0)
# Requirement already satisfied, skipping upgrade: gym in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pddlgym==0.0.2) (0.17.2)
# Requirement already satisfied, skipping upgrade: imageio in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pddlgym==0.0.2) (2.9.0)
# Requirement already satisfied, skipping upgrade: scikit-image in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pddlgym==0.0.2) (0.17.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from matplotlib->pddlgym==0.0.2) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from matplotlib->pddlgym==0.0.2) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from matplotlib->pddlgym==0.0.2) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from matplotlib->pddlgym==0.0.2) (1.2.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from matplotlib->pddlgym==0.0.2) (1.19.1)
# Requirement already satisfied, skipping upgrade: certifi>=2020.06.20 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from matplotlib->pddlgym==0.0.2) (2020.6.20)
# Requirement already satisfied, skipping upgrade: cloudpickle<1.4.0,>=1.2.0 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from gym->pddlgym==0.0.2) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyglet<=1.5.0,>=1.4.0 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from gym->pddlgym==0.0.2) (1.5.0)
# Requirement already satisfied, skipping upgrade: scipy in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from gym->pddlgym==0.0.2) (1.5.2)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-image->pddlgym==0.0.2) (2.4)
# Requirement already satisfied, skipping upgrade: PyWavelets>=1.1.1 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-image->pddlgym==0.0.2) (1.1.1)
# Requirement already satisfied, skipping upgrade: tifffile>=2019.7.26 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from scikit-image->pddlgym==0.0.2) (2020.9.3)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from python-dateutil>=2.1->matplotlib->pddlgym==0.0.2) (1.15.0)
# Requirement already satisfied, skipping upgrade: future in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from pyglet<=1.5.0,>=1.4.0->gym->pddlgym==0.0.2) (0.18.2)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (from networkx>=2.0->scikit-image->pddlgym==0.0.2) (4.4.2)
# Building wheels for collected packages: pddlgym
#   Building wheel for pddlgym (setup.py) ... done
#   Created wheel for pddlgym: filename=pddlgym-0.0.2-py3-none-any.whl size=5228756 sha256=06f840df2ee86eb946c2632cabde275f82f1246703867d97a2b60b23c3f7c0b0
#   Stored in directory: /private/var/folders/2y/1l8njzj51qd7b7jnwzz5v2bm0000gn/T/pip-ephem-wheel-cache-kfdlta2w/wheels/70/00/da/84f1ea25112e85e8e4218a6905deae211edd977267c483f457
# Successfully built pddlgym
# Installing collected packages: pddlgym
#   Attempting uninstall: pddlgym
#     Found existing installation: pddlgym 0.0.2
#     Uninstalling pddlgym-0.0.2:
#       Successfully uninstalled pddlgym-0.0.2
# Successfully installed pddlgym-0.0.2
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/Users/tom/.pyenv/versions/3.6.7/bin/python3.6 -m pip install --upgrade pip' command.
# Requirement already satisfied: tabulate in /Users/tom/.pyenv/versions/3.6.7/lib/python3.6/site-packages (0.8.7)
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/Users/tom/.pyenv/versions/3.6.7/bin/python3.6 -m pip install --upgrade pip' command.

# %%
import abc
import pddlgym
import heapq as hq
import numpy as np
import time
from itertools import count
from collections import defaultdict, namedtuple
from tabulate import tabulate

# %% [markdown]
# ## A Generic Approach for PO Environments
#
# An agent maintains a belief state and produces actions.

# %%
class PartialObservabilityApproach:
    """An agent that maintains a belief state (set of possible states)
    as it takes actions and receives partial observations.

    Parameters
    ----------
    actions : [ int ]
        A list of actions that the agent can take. All actions are
        applicable in all states.
    successor_fn : state, action -> state
        Maps an environment state and action to a next state.
    check_goal_fn : state -> bool
        Maps an environment state to true when the goal is reached.
    observation_fn : state -> observation
        Maps an environment state to an observation. Sometimes
        called "Percept".
    observation_to_states_fn : observation -> frozenset{states}
        Maps an observation to the set of environment states such
        that observation_fn(state) would produce that observation.
    """
    def __init__(self, actions, successor_fn, check_goal_fn, 
                 observation_fn, observation_to_states_fn):
        self._actions = actions
        self._successor_fn = successor_fn
        self._check_goal_fn = check_goal_fn
        self._observation_fn = observation_fn
        self._observation_to_states_fn = observation_to_states_fn
        self._step_count = 0
        self._belief_state = None # set after reset
        self._rng = None

    def reset(self, obs):
        """Tell the agent that we have started a new problem with
        initial observation "obs".

        Parameters
        ----------
        obs : hashable
            The initial observation

        Returns
        -------
        info : dict
            Any useful debug info.
        """
        # Reset the belief state
        self._belief_state = self._observation_to_states_fn(obs)
        # Reset step count
        self._step_count = 0
        return {}

    def step(self, obs):
        """Receive an observation and produce an action to be
        immediately executed in the environment.

        Parameters
        ----------
        obs : hashable
            The observation

        Returns
        -------
        action : int
            The action is assumed to be immediately taken.
        info : dict
            Any useful debug info.
        """
        # Update the belief state based on the observation
        possible_states = self._observation_to_states_fn(obs)
        # This is set intersection
        self._belief_state &= possible_states
        # Find an action
        action, info = self._get_action()
        # Update step count
        self._step_count += 1
        # Update the belief state based on action
        self._belief_state = self._predict_belief_state(self._belief_state, 
            action)
        return action, info

    def seed(self, seed):
        """Seed the agent, just in case it's random
        """
        self._rng = np.random.RandomState(seed)

    @abc.abstractmethod
    def _get_action(self):
        """Return an action to be immediately taken, based on the current
        belief state (self._belief_state). This is the main thing that
        differentiates subclasses.

        Returns
        -------
        action : int
            The action to be taken immediately.
        info : dict
            Any useful debug info.
        """
        raise NotImplementedError("Override me")

    def _check_belief_state_goal(self, belief_state):
        """Check whether the belief state is a goal, that is, whether
        all states in the belief state satisify the check_goal_fn.

        This function is included here because it is likely to be
        used by subclasses.

        Parameters
        ----------
        belief_state : frozenset{hashable}

        Returns
        -------
        goal_reached : bool
        """
        # We've found a goal if all states in the belief state are at goals
        for state in belief_state:
            if not self._check_goal_fn(state):
                return False
        return True

    def _predict_belief_state(self, belief_state, action):
        """Get the next belief state that would result after taking
        action in belief_state.

        This function is included here because it is likely to be
        used by subclasses.

        Parameters
        ----------
        belief_state : frozenset{hashable}
        action : int

        Returns
        -------
        next_belief_state : frozenset{hashable}
        """
        next_belief_state = set()
        for state in belief_state:
            next_state = self._successor_fn(state, action)
            next_belief_state.add(next_state)
        return frozenset(next_belief_state)

# %% [markdown]
# ### Random Actions Approach

# %%
class RandomActions(PartialObservabilityApproach):
    """Take random actions
    """
    def _get_action(self):
        return self._rng.choice(self._actions), {}

# %% [markdown]
# ### Depth-first And-Or Search

# %%
class AndOrSearch(PartialObservabilityApproach):
    """Exhaustive depth-first And-Or search (Russell-Norvig version)
    """

    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self._conditional_plan = "failure"
        self._num_expansions = None # set in reset

    def _get_action(self):
        """Return an action to be immediately taken, based on the current
        belief state (self._belief_state).

        Returns
        -------
        action : int
            The action to be taken immediately.
        info : dict
            Any useful debug info.
        """
        info = {}
        # Check if it's time to replan
        if self._step_count == 0 or self._conditional_plan == "failure":
            action, self._conditional_plan = self._get_conditional_plan()
            info["node_expansions"] = next(self._num_expansions)-1
            self._num_expansions = None
        else:
            action, self._conditional_plan = self._conditional_plan[self._belief_state]
        return action, info

    def _get_conditional_plan(self):
        """Run planning from scratch, given the current belief state
        """
        # Reset expansion counter
        self._num_expansions = count()
        # Start off the AND-OR search
        return self._run_or_search(self._belief_state, [])

    def _run_or_search(self, belief_state, path, depth=0, max_depth=np.inf, verbose=True):
        """Run OR part of AO search (recursively).

        Parameters
        ----------
        belief_state : frozenset{hashable}
        path : [ belief_state ]
            Belief states encountered so far, used to find cycles.
        depth : int
        max_depth : int

        Returns
        -------
        conditional_plan : Any
            Representation of the conditional plan.
        """
        # Max depth exceeded
        if depth > max_depth:
            return "failure"
        if self._check_belief_state_goal(belief_state):
            return "success"
        # Check if we've visited this belief state already
        if belief_state in path:
            return "failure"
        # Consider each possible action, depth-first order
        num_expansions = next(self._num_expansions)
        if verbose:
            print(f"Expanding OR  node {num_expansions}", end='\r', flush=True)
        for action in self._actions:
            next_belief_states = self._get_belief_successor_states(belief_state, action)
            conditional_plan = self._run_and_search(next_belief_states, [belief_state] + path,
                depth=depth, max_depth=max_depth, verbose=verbose)
            if conditional_plan != "failure":
                return (action, conditional_plan)
        return "failure"

    def _run_and_search(self, belief_states, path, depth=0, max_depth=np.inf, verbose=True):
        """Run AND part of the AO search (recursively).

        Parameters
        ----------
        belief_states : [frozenset{hashabale}]
            A list of belief states.
        path : [ belief_state ]
            Belief states encountered so far, used to find cycles.
        depth : int
        max_depth : int

        Returns
        -------
        conditional_plan : Any
            Representation of the conditional plan.
        """
        plans = []
        num_expansions = next(self._num_expansions)
        if verbose:
            print(f"Expanding AND node {num_expansions}", end='\r', flush=True)
        for belief_state in belief_states:
            plan = self._run_or_search(belief_state, path, depth=depth+1, 
                                       max_depth=max_depth, verbose=verbose)
            if plan == "failure":
                return "failure"
            plans.append(plan)
        return dict(zip(belief_states, plans))

    def _get_belief_successor_states(self, belief_state, action):
        """Get the next possible belief states based on possible
        observations, after taking action in belief_state.

        Parameters
        ----------
        belief_state : frozenset{hashable}
        action : int

        Returns
        -------
        next_belief_states : [frozenset{hashabale}]
            A list of belief states.
        """
        # Prediction
        next_belief_state = self._predict_belief_state(belief_state, action)
        # Possible percepts and update
        possible_percept_to_states = defaultdict(list)
        for s in next_belief_state:
            o = self._observation_fn(s)
            possible_percept_to_states[o].append(s)
        # Sorting to ensure determinism
        belief_states = sorted(frozenset(bs) for bs in possible_percept_to_states.values())
        return belief_states

# %% [markdown]
# ### Iterative Deepening And-Or Search

# %%
class IterativeDeepeningAndOrSearch(AndOrSearch):
    """Run AndOrSearch with progressively larger depth limits until a plan is found.
    """
    def _get_conditional_plan(self):
        """Run planning from scratch, given the current belief state
        """
        # Reset expansion counter
        self._num_expansions = count()
        # Run iterative deepening planning until plan is not a failure
        for max_depth in count(1):
            print(f"Running iterative deepening with depth {max_depth}", end='\r', flush=True)
            conditional_plan = self._run_or_search(self._belief_state, [], 
                depth=0, max_depth=max_depth, verbose=False)
            if conditional_plan != "failure":
                print()
                break
        return conditional_plan

# %% [markdown]
# ### AStar Planner
# Used by Single State Determinization.

# %%
class AStar:
    """Planning with A* search. Used by SingleStateDeterminization.
    """
    
    Node = namedtuple("Node", ["state", "parent", "action", "g"])

    def __init__(self, successor_fn, check_goal_fn, heuristic=None, timeout=100):
        self._get_successor_state = successor_fn
        self._check_goal = check_goal_fn
        self._heuristic = heuristic or (lambda s : 0)
        self._timeout = timeout
        self._actions = None
        
    def __call__(self, state, verbose=True):
        return self._get_plan(state, verbose=verbose)

    def set_actions(self, actions):
        self._actions = actions

    def _get_plan(self, state, verbose=True):
        start_time = time.time()
        queue = []
        state_to_best_g = defaultdict(lambda : float("inf"))
        tiebreak = count()

        root_node = self.Node(state=state, parent=None, action=None, g=0)
        hq.heappush(queue, (self._get_priority(root_node), next(tiebreak), root_node))
        num_expansions = 0

        while len(queue) > 0 and (time.time() - start_time < self._timeout):
            _, _, node = hq.heappop(queue)
            # If we already found a better path here, don't bother
            if state_to_best_g[node.state] < node.g:
                continue
            # If the goal holds, return
            if self._check_goal(node.state):
                if verbose:
                    print("\nPlan found!")
                return self._finish_plan(node), {'node_expansions' : num_expansions}
            num_expansions += 1
            if verbose:
                print(f"Expanding node {num_expansions}", end='\r', flush=True)
            # Generate successors
            for action, child_state in self._get_successors(node.state):
                # If we already found a better path to child, don't bother
                if state_to_best_g[child_state] <= node.g+1:
                    continue
                # Add new node
                child_node = self.Node(state=child_state, parent=node, action=action, g=node.g+1)
                priority = self._get_priority(child_node)
                hq.heappush(queue, (priority, next(tiebreak), child_node))
                state_to_best_g[child_state] = child_node.g

        if verbose:
            print("Warning: planning failed.")
        return [], {'node_expansions' : num_expansions}
    
    def _get_successors(self, state):
        for action in self._actions:
            next_state = self._get_successor_state(state, action)
            yield action, next_state

    def _finish_plan(self, node):
        plan = []
        while node.parent is not None:
            plan.append(node.action)
            node = node.parent
        plan.reverse()
        return plan

    def _get_priority(self, node):
        h = self._heuristic(node)
        if isinstance(h, tuple):
            return (tuple(node.g + hi for hi in h), h)
        return (node.g + h, h)

# %% [markdown]
# ### Single State Determinization

# %%
class SingleStateDeterminization(PartialObservabilityApproach):
    """Arbitrarily select a state from the belief state and then
    do uniform cost search.
    """
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self._plan = []
        self._planner = AStar(self._successor_fn, self._check_goal_fn)
        self._planner.set_actions(self._actions)
        self._expected_states = []

    def _get_action(self):
        """Return an action to be immediately taken, based on the current
        belief state (self._belief_state).

        Returns
        -------
        action : int
            The action to be taken immediately.
        info : dict
            Any useful debug info.
        """
        info = {}
        # Check if it's time to replan. If we're out of a plan, definitely replan.
        expected_state = None if len(self._expected_states) == 0 else self._expected_states.pop(0)
        if self._step_count == 0 or not self._plan or expected_state not in self._belief_state:
            self._plan, info = self._get_plan()
        if not self._plan:
            print("Warning: step was called without a plan. Defaulting to random action.")
            return self._rng.choice(self._actions), info
        action = self._plan.pop(0)
        return action, info

    def _get_plan(self):
        """Determinize and plan

        Returns
        -------
        plan : [ int ]
            A sequence of actions.
        """
        # Determinize by selecting a random state
        choices = sorted(self._belief_state)
        state = choices[self._rng.randint(len(choices))]
        # Plan
        plan, info = self._planner(state)
        # Get expected states
        s = state
        self._expected_states = []
        for a in plan:
            s = self._successor_fn(s, a)
            self._expected_states.append(s)
        return plan, info

# %% [markdown]
# ### UCT Planner
# Used by PO-UCT.

# %%
class UCT:
    """Implementation of UCT based on Leslie's lecture notes. Used by POUCT.
    """
    def __init__(self, actions, reward_fn, transition_fn, done_fn=None, num_search_iters=100, gamma=0.9):
        self._actions = actions
        self._reward_fn = reward_fn
        self._transition_fn = transition_fn
        self._done_fn = done_fn or (lambda s,a : False)
        self._num_search_iters = num_search_iters
        self._gamma = gamma
        self._rng = None # set in seed
        self._Q = None
        self._N = None
        self._node_expansions = 0

    def run(self, state, horizon=100):
        # Initialize Q[s][a][d] -> float
        self._Q = defaultdict(lambda : defaultdict(lambda : defaultdict(float)))
        # Initialize N[s][a][d] -> int
        self._N = defaultdict(lambda : defaultdict(lambda : defaultdict(int)))
        # Loop search
        for it in range(self._num_search_iters):
            # Update Q
            self._search(state, 0, horizon=horizon)
        info = {"node_expansions" : self._node_expansions}
        self._node_expansions = 0
        return info

    def get_action(self, state, t=0):
        # Return best action, break ties randomly
        return max(self._actions, key=lambda a : (self._Q[state][a][t], self._rng.uniform()))

    def _search(self, s, depth, horizon=100):
        # Base case
        if depth == horizon:
            return 0.
        # Select an action, balancing explore/exploit
        a = self._select_action(s, depth, horizon=horizon)
        # Create a child state
        next_state = self._transition_fn(s, a)
        self._node_expansions += 1
        # Get value estimate
        if self._done_fn(s, a):
            # Some environments terminate problems before the horizon 
            q = self._reward_fn(s, a)
        else:
            q = self._reward_fn(s, a) + self._gamma * self._search(next_state, depth+1, horizon=horizon)
        # Update values and counts
        num_visits = self._N[s][a][depth] # before now
        # First visit to (s, a, depth)
        if num_visits == 0:
            self._Q[s][a][depth] = q
        # We've been here before
        else:
            # Running average
            self._Q[s][a][depth] = (num_visits / (num_visits + 1.)) * self._Q[s][a][depth] + \
                                   (1 / (num_visits + 1.)) * q
        # Update num visits
        self._N[s][a][depth] += 1
        return self._Q[s][a][depth]

    def _select_action(self, s, depth, horizon):
        # If there is any action where N(s, a, depth) == 0, try it first
        untried_actions = [a for a in self._actions if self._N[s][a][depth] == 0]
        if len(untried_actions) > 0:
            return self._rng.choice(untried_actions)
        # Otherwise, take an action to trade off exploration and exploitation
        N_s_d = sum(self._N[s][a][depth] for a in self._actions)
        best_action_score = -np.inf
        best_actions = []
        for a in self._actions:
            explore_bonus = (np.log(N_s_d) / self._N[s][a][depth])**((horizon + depth) / (2*horizon + depth))
            score = self._Q[s][a][depth] + explore_bonus
            if score > best_action_score:
                best_action_score = score
                best_actions = [a]
            elif score == best_action_score:
                best_actions.append(a)
        return self._rng.choice(best_actions)

    def seed(self, seed):
        self._rng = np.random.RandomState(seed)

# %% [markdown]
# ### PO-UCT

# %%
class POUCT(PartialObservabilityApproach):
    """Use UCT in belief space; sample belief state transitions uniformly at random
    """
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self._planner = UCT(self._actions, self._get_uct_reward, self._get_uct_transition,
                            done_fn=lambda s,a:self._check_belief_state_goal(s),
                            num_search_iters=100, gamma=0.9)
        self._steps_since_replanning = 0
        self._replanning_interval = 1
        self._horizon = 50

    def _get_action(self):
        """Return an action to be immediately taken, based on the current
        belief state (self._belief_state).

        Returns
        -------
        action : int
            The action to be taken immediately.
        info : dict
            Any useful debug info.
        """
        info = {}
        # Replan on a fixed interval
        if self._step_count % self._replanning_interval == 0:
            info = self._planner.run(self._belief_state, horizon=self._horizon)
            self._steps_since_replanning = 0
        action = self._planner.get_action(self._belief_state, t=self._steps_since_replanning)
        self._steps_since_replanning += 1
        return action, info

    def _get_plan(self):
        """Determinize and plan

        Returns
        -------
        plan : [ int ]
            A sequence of actions.
        """
        self._planner.run(self._belief_state)
        return self._planner.get_action(self._belief_state)

    def _get_uct_reward(self, belief_state, _):
        """Use a sparse reward: 1.0 if the goal is reached, 0 otherwise

        Parameters
        ----------
        belief_state : frozenset{hashable}

        Returns
        -------
        reward : float
        """
        return float(self._check_belief_state_goal(belief_state))

    def _get_uct_transition(self, belief_state, action):
        """Sample uniformly at random among the possible next belief states
        """
        choices = self._get_belief_successor_states(belief_state, action)
        state = choices[self._rng.randint(len(choices))]
        return state

    def _get_belief_successor_states(self, belief_state, action):
        """Get the next possible belief states based on possible
        observations, after taking action in belief_state.

        Parameters
        ----------
        belief_state : frozenset{hashable}
        action : int

        Returns
        -------
        next_belief_states : [frozenset{hashabale}]
            A list of belief states.
        """
        # Prediction
        next_belief_state = self._predict_belief_state(belief_state, action)
        # Possible percepts and update
        possible_percept_to_states = defaultdict(list)
        for s in next_belief_state:
            o = self._observation_fn(s)
            possible_percept_to_states[o].append(s)
        # Sorting to ensure determinism
        belief_states = sorted(frozenset(bs) for bs in possible_percept_to_states.values())
        return belief_states

    def seed(self, seed):
        """Also seed the planner
        """
        super().seed(seed)
        self._planner.seed(seed)

# %% [markdown]
# ## Evaluation Pipeline

# %%
def run_single_test(test_env, problem_idx, model, max_horizon=100):
    print(f"Running test problem {problem_idx}")
    test_env.fix_problem_index(problem_idx)
    start_time = time.time()
    obs, info = test_env.reset()
    model_info = model.reset(obs)
    num_steps = 0
    expansions = model_info.get("node_expansions", 0)
    success = False
    for t in range(max_horizon):
        print(".", end='', flush=True)
        act, model_info = model.step(obs)
        expansions += model_info.get("node_expansions", 0)
        obs, reward, done, info = test_env.step(act)
        num_steps += 1
        if done:
            assert reward == 1
            success = True
            break
    duration = time.time() - start_time
    print(f" final duration: {duration} with num steps {num_steps} and success={success}.")
    return duration, expansions, num_steps, success

def run_single_experiment(model, env, seed=0):
    # Initialize
    model.seed(seed)
    env.seed(seed)

    # Do testing
    test_durations = [] # seconds, one per problem
    test_expansions = [] # integers
    test_num_steps = [] # integers
    test_successes = [] # boolean, True if successful
    for problem_idx in range(len(env.problems)):
        duration, expansions, num_steps, success = \
            run_single_test(env, problem_idx, model)
        test_durations.append(duration)
        test_expansions.append(expansions)
        test_num_steps.append(num_steps)
        test_successes.append(success)

    env.close()

    return test_durations, test_expansions, test_num_steps, test_successes

def get_approach(name, env, planning_timeout=10):
    if name == "random":
        return RandomActions(env.get_possible_actions(), env.get_successor_state, 
                             env.check_goal, env.get_observation, env.observation_to_states)

    if name == "depth_first_and_or_search":
        return AndOrSearch(env.get_possible_actions(), env.get_successor_state, 
                           env.check_goal, env.get_observation, env.observation_to_states)

    if name == "iterative_deepening_and_or_search":
        return IterativeDeepeningAndOrSearch(env.get_possible_actions(), env.get_successor_state, 
                                             env.check_goal, env.get_observation, env.observation_to_states)

    if name == "single_state_determinization":
        return SingleStateDeterminization(env.get_possible_actions(), env.get_successor_state, 
                                          env.check_goal, env.get_observation, env.observation_to_states)

    if name == "pouct":
        return POUCT(env.get_possible_actions(), env.get_successor_state, 
                     env.check_goal, env.get_observation, env.observation_to_states)


    raise Exception(f"Unrecognized approach: {name}")

def print_results_table(env_name, results_for_env):
    print(f"\n### {env_name} ###")
    mean_table = [(a, ) + tuple(np.mean(results_for_env[a], axis=0)) \
                  for a in sorted(results_for_env)]
    columns = ["Approach", "Duration", "Expansions", "Num Steps", "Successes"]
    print(tabulate(mean_table, headers=columns))

def main():
    approaches = [
        "random", 
        "depth_first_and_or_search",
        "iterative_deepening_and_or_search",
        "single_state_determinization",
        "pouct",
    ]
    num_seeds_per_approach = {
        "random" : 10,
        "depth_first_and_or_search" : 1,
        "iterative_deepening_and_or_search" : 1,
        "single_state_determinization" : 10,
        "pouct" : 10,
    }

    env_names = [
        "SmallPOSARRadius0",
        "POSARRadius1",
        "POSARRadius0",
        "POSARRadius1Xray", 
        "POSARRadius0Xray",
    ]

    all_results = {}
    for env_name in env_names:
        results_for_env = {}
        all_results[env_name] = results_for_env
        for approach in approaches:
            results_for_env[approach] = []
            env = pddlgym.make(f"{env_name}-v0")
            model = get_approach(approach, env)
            for seed in range(num_seeds_per_approach[approach]):
                results = run_single_experiment(model, env, seed=seed)
                for (dur, expansions, num_steps, succ) in zip(*results):
                    results_for_env[approach].append((dur, expansions, num_steps, succ))

        # Print per-environment results (because of impatience)
        print_results_table(env_name, results_for_env)

    # Print final results
    print("\n" + "*" * 80)
    for env_name in env_names:
        print_results_table(env_name, all_results[env_name])

# %% [markdown]
# ### Fire Away!

# %%
main()
# Out:
# Running test problem 0
# .............................................. final duration: 0.04323410987854004 with num steps 46 and success=True.
# Running test problem 1
# .. final duration: 0.0013530254364013672 with num steps 2 and success=True.
# Running test problem 2
# .................................................................................... final duration: 0.07806396484375 with num steps 84 and success=True.
# Running test problem 3
# ................................................................................ final duration: 0.06100296974182129 with num steps 80 and success=True.
# Running test problem 4
# .............................................. final duration: 0.04190182685852051 with num steps 46 and success=True.
# Running test problem 5
# ........... final duration: 0.009466886520385742 with num steps 11 and success=True.
# Running test problem 0
# ................................................................................... final duration: 0.06172990798950195 with num steps 83 and success=True.
# Running test problem 1
# ............................................................................................ final duration: 0.08923602104187012 with num steps 92 and success=True.
# Running test problem 2
# ................................................................... final duration: 0.05086827278137207 with num steps 67 and success=True.
# Running test problem 3
# ............ final duration: 0.006678104400634766 with num steps 12 and success=True.
# Running test problem 4
# ................................................... final duration: 0.04344797134399414 with num steps 51 and success=True.
# Running test problem 5
# .................... final duration: 0.01914381980895996 with num steps 20 and success=True.
# Running test problem 0
# ........................................................ final duration: 0.046730995178222656 with num steps 56 and success=True.
# Running test problem 1
# .............................................. final duration: 0.04748892784118652 with num steps 46 and success=True.
# Running test problem 2
# ............................................................. final duration: 0.050215959548950195 with num steps 61 and success=True.
# Running test problem 3
# ........ final duration: 0.008060216903686523 with num steps 8 and success=True.
# Running test problem 4
# ... final duration: 0.0016617774963378906 with num steps 3 and success=True.
# Running test problem 5
# .................................... final duration: 0.0371699333190918 with num steps 36 and success=True.
# Running test problem 0
# ................................................................................. final duration: 0.07686209678649902 with num steps 81 and success=True.
# Running test problem 1
# ................. final duration: 0.019185781478881836 with num steps 17 and success=True.
# Running test problem 2
# ................................. final duration: 0.03255820274353027 with num steps 33 and success=True.
# Running test problem 3
# ................................................................................... final duration: 0.07313799858093262 with num steps 83 and success=True.
# Running test problem 4
# ....................................................... final duration: 0.054875850677490234 with num steps 55 and success=True.
# Running test problem 5
# .............................................................................................. final duration: 0.09722089767456055 with num steps 94 and success=True.
# Running test problem 0
# ............................... final duration: 0.027394771575927734 with num steps 31 and success=True.
# Running test problem 1
# ......................... final duration: 0.028880834579467773 with num steps 25 and success=True.
# Running test problem 2
# .............. final duration: 0.011710882186889648 with num steps 14 and success=True.
# Running test problem 3
# .................................................. final duration: 0.04343104362487793 with num steps 50 and success=True.
# Running test problem 4
# .................................................................... final duration: 0.07000112533569336 with num steps 68 and success=True.
# Running test problem 5
# ......................................... final duration: 0.042000770568847656 with num steps 41 and success=True.
# Running test problem 0
# ............................. final duration: 0.030108213424682617 with num steps 29 and success=True.
# Running test problem 1
# ........................................... final duration: 0.038294076919555664 with num steps 43 and success=True.
# Running test problem 2
# ........................................................... final duration: 0.060303688049316406 with num steps 59 and success=True.
# Running test problem 3
# ................................. final duration: 0.03733396530151367 with num steps 33 and success=True.
# Running test problem 4
# ........................................... final duration: 0.0503232479095459 with num steps 43 and success=True.
# Running test problem 5
# ............................... final duration: 0.028931140899658203 with num steps 31 and success=True.
# Running test problem 0
# .................................................................................................... final duration: 0.0978689193725586 with num steps 100 and success=False.
# Running test problem 1
# .......................................... final duration: 0.045751094818115234 with num steps 42 and success=True.
# Running test problem 2
# .................................................................................................... final duration: 0.10250020027160645 with num steps 100 and success=False.
# Running test problem 3
# ................................................... final duration: 0.05227303504943848 with num steps 51 and success=True.
# Running test problem 4
# ...... final duration: 0.005191802978515625 with num steps 6 and success=True.
# Running test problem 5
# ........................................................................................ final duration: 0.08293414115905762 with num steps 88 and success=True.
# Running test problem 0
# .............. final duration: 0.015622854232788086 with num steps 14 and success=True.
# Running test problem 1
# .............................................................................. final duration: 0.07725977897644043 with num steps 78 and success=True.
# Running test problem 2
# ........................................................ final duration: 0.05584907531738281 with num steps 56 and success=True.
# Running test problem 3
# .................................................................................................... final duration: 0.09831094741821289 with num steps 100 and success=False.
# Running test problem 4
# ................................................................. final duration: 0.0665891170501709 with num steps 65 and success=True.
# Running test problem 5
# .................................................................................................... final duration: 0.10262703895568848 with num steps 100 and success=False.
# Running test problem 0
# .......................................... final duration: 0.03793787956237793 with num steps 42 and success=True.
# Running test problem 1
# ............................................. final duration: 0.04023098945617676 with num steps 45 and success=True.
# Running test problem 2
# ............................................. final duration: 0.04289817810058594 with num steps 45 and success=True.
# Running test problem 3
# ..................... final duration: 0.020009994506835938 with num steps 21 and success=True.
# Running test problem 4
# ........................................................... final duration: 0.056114912033081055 with num steps 59 and success=True.
# Running test problem 5
# ...................... final duration: 0.02113795280456543 with num steps 22 and success=True.
# Running test problem 0
# ..................... final duration: 0.018911123275756836 with num steps 21 and success=True.
# Running test problem 1
# .. final duration: 0.0025606155395507812 with num steps 2 and success=True.
# Running test problem 2
# ................................................................................ final duration: 0.07500791549682617 with num steps 80 and success=True.
# Running test problem 3
# ................................................................................ final duration: 0.0765681266784668 with num steps 80 and success=True.
# Running test problem 4
# ................ final duration: 0.015057802200317383 with num steps 16 and success=True.
# Running test problem 5
# ................................................................................ final duration: 0.06880474090576172 with num steps 80 and success=True.
# Running test problem 0
# Expanding OR  node 1549
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# .xpanding AND node 2409 final duration: 1.3164002895355225 with num steps 2 and success=True.
# Running test problem 2
# Expanding OR  node 757
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# .xpanding OR  node 2174xpanding AND node 1107. final duration: 1.2165472507476807 with num steps 4 and success=True.
# Running test problem 5
# Expanding AND node 166
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Running iterative deepening with depth 9
# ........ final duration: 1.0651578903198242 with num steps 9 and success=True.
# Running test problem 3
# Running iterative deepening with depth 91
# .... final duration: 1.0503370761871338 with num steps 5 and success=True.
# Running test problem 4
# Running iterative deepening with depth 91
# ..... final duration: 1.0691628456115723 with num steps 6 and success=True.
# Running test problem 5
# Running iterative deepening with depth 91
# ...... final duration: 1.0747861862182617 with num steps 7 and success=True.
# Running test problem 0
# Expanding node 10
# Plan found!
# Expanding node 10
# Plan found!
# ... final duration: 0.019650697708129883 with num steps 5 and success=True.
# Running test problem 1
# Expanding node 10
# Plan found!
# Expanding node 9 1
# Plan found!
# Expanding node 101
# Plan found!
# ... final duration: 0.026302099227905273 with num steps 8 and success=True.
# Running test problem 2
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 8e 1
# Plan found!
# . final duration: 0.0226590633392334 with num steps 7 and success=True.
# Running test problem 3
# Expanding node 10
# Plan found!
# Expanding node 10
# Plan found!
# Expanding node 9e 1
# Plan found!
# Expanding node 101
# Plan found!
# .... final duration: 0.028480052947998047 with num steps 11 and success=True.
# Running test problem 4
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 5e 1
# Plan found!
#  final duration: 0.0191650390625 with num steps 6 and success=True.
# Running test problem 5
# Expanding node 10
# Plan found!
# Expanding node 8 1
# Plan found!
# Expanding node 7 1
# Plan found!
# Expanding node 81
# Plan found!
# . final duration: 0.02469611167907715 with num steps 7 and success=True.
# Running test problem 0
# Expanding node 10
# Plan found!
# Expanding node 9 1
# Plan found!
# Expanding node 8 1
# Plan found!
# .. final duration: 0.019678115844726562 with num steps 7 and success=True.
# Running test problem 1
# Expanding node 10
# Plan found!
# Expanding node 51
# Plan found!
#  final duration: 0.007146120071411133 with num steps 2 and success=True.
# Running test problem 2
# Expanding node 81
# Plan found!
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# ... final duration: 0.023637056350708008 with num steps 7 and success=True.
# Running test problem 3
# Expanding node 10
# Plan found!
# Expanding node 9 1
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 8e 1
# Plan found!
# . final duration: 0.025708675384521484 with num steps 9 and success=True.
# Running test problem 4
# Expanding node 10
# Plan found!
# . final duration: 0.009469032287597656 with num steps 2 and success=True.
# Running test problem 5
# Expanding node 10
# Plan found!
# .. final duration: 0.010751008987426758 with num steps 3 and success=True.
# Running test problem 0
# Expanding node 10
# Plan found!
# .. final duration: 0.0067288875579833984 with num steps 3 and success=True.
# Running test problem 1
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 5e 1
# Plan found!
#  final duration: 0.019202232360839844 with num steps 6 and success=True.
# Running test problem 2
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# .... final duration: 0.016308069229125977 with num steps 7 and success=True.
# Running test problem 3
# Expanding node 10
# Plan found!
# .. final duration: 0.007627964019775391 with num steps 3 and success=True.
# Running test problem 4
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 5e 1
# Plan found!
#  final duration: 0.022178173065185547 with num steps 6 and success=True.
# Running test problem 5
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 4 1
# Plan found!
#  final duration: 0.019134044647216797 with num steps 5 and success=True.
# Running test problem 0
# Expanding node 10
# Plan found!
# Expanding node 9 1
# Plan found!
# .. final duration: 0.0149688720703125 with num steps 5 and success=True.
# Running test problem 1
# Expanding node 81
# Plan found!
# . final duration: 0.006905078887939453 with num steps 2 and success=True.
# Running test problem 2
# Expanding node 10
# Plan found!
# Expanding node 8 1
# Plan found!
# Expanding node 7 1
# Plan found!
# Expanding node 81
# Plan found!
# . final duration: 0.027444839477539062 with num steps 7 and success=True.
# Running test problem 3
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 10 1
# Plan found!
# ... final duration: 0.024751901626586914 with num steps 9 and success=True.
# Running test problem 4
# Expanding node 10
# Plan found!
# Expanding node 8 1
# Plan found!
# Expanding node 9 1
# Plan found!
# Expanding node 51
# Plan found!
#  final duration: 0.01987004280090332 with num steps 6 and success=True.
# Running test problem 5
# Expanding node 81
# Plan found!
# Expanding node 10
# Plan found!
# Expanding node 10 1
# Plan found!
# Expanding node 8de 1
# Plan found!
# .. final duration: 0.02564096450805664 with num steps 11 and success=True.
# Running test problem 0
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 8e 1
# Plan found!
# Expanding node 81
# Plan found!
# .. final duration: 0.027291059494018555 with num steps 9 and success=True.
# Running test problem 1
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# ... final duration: 0.015841007232666016 with num steps 6 and success=True.
# Running test problem 2
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 8de 1
# Plan found!
# .. final duration: 0.017978906631469727 with num steps 9 and success=True.
# Running test problem 3
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 4 1
# Plan found!
#  final duration: 0.01612687110900879 with num steps 5 and success=True.
# Running test problem 4
# Expanding node 81
# Plan found!
# Expanding node 10
# Plan found!
# Expanding node 5 1
# Plan found!
#  final duration: 0.016299962997436523 with num steps 4 and success=True.
# Running test problem 5
# Expanding node 10
# Plan found!
# Expanding node 10
# Plan found!
# Expanding node 8 1
# Plan found!
# Expanding node 91
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 4 1
# Plan found!
#  final duration: 0.03315925598144531 with num steps 9 and success=True.
# Running test problem 0
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 4 1
# Plan found!
#  final duration: 0.017749786376953125 with num steps 5 and success=True.
# Running test problem 1
# Expanding node 10
# Plan found!
# Expanding node 8 1
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 8de 1
# Plan found!
# Expanding node 7 1
# Plan found!
# . final duration: 0.03068709373474121 with num steps 12 and success=True.
# Running test problem 2
# Expanding node 81
# Plan found!
# Expanding node 81
# Plan found!
# Expanding node 91
# Plan found!
# .. final duration: 0.012740135192871094 with num steps 5 and success=True.
# Running test problem 3
# Expanding node 10
# Plan found!
# .. final duration: 0.010529041290283203 with num steps 3 and success=True.
# Running test problem 4
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# ... final duration: 0.014597892761230469 with num steps 6 and success=True.
# Running test problem 5
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# .... final duration: 0.016302108764648438 with num steps 7 and success=True.
# Running test problem 0
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 8de 1
# Plan found!
# .. final duration: 0.02223825454711914 with num steps 9 and success=True.
# Running test problem 1
# Expanding node 10
# Plan found!
# Expanding node 8 1
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 8de 1
# Plan found!
# Expanding node 7 1
# Plan found!
# . final duration: 0.02808213233947754 with num steps 12 and success=True.
# Running test problem 2
# Expanding node 10
# Plan found!
# .. final duration: 0.009244918823242188 with num steps 3 and success=True.
# Running test problem 3
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 4 1
# Plan found!
#  final duration: 0.01708388328552246 with num steps 5 and success=True.
# Running test problem 4
# Expanding node 81
# Plan found!
# Expanding node 81
# Plan found!
# Expanding node 81
# Plan found!
# Expanding node 9 1
# Plan found!
# Expanding node 51
# Plan found!
#  final duration: 0.02514505386352539 with num steps 6 and success=True.
# Running test problem 5
# Expanding node 81
# Plan found!
# Expanding node 10
# Plan found!
# Expanding node 10 1
# Plan found!
# Expanding node 8de 1
# Plan found!
# .. final duration: 0.027543067932128906 with num steps 11 and success=True.
# Running test problem 0
# Expanding node 10
# Plan found!
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 8e 1
# Plan found!
# .. final duration: 0.027357816696166992 with num steps 9 and success=True.
# Running test problem 1
# Expanding node 81
# Plan found!
# . final duration: 0.004728794097900391 with num steps 2 and success=True.
# Running test problem 2
# Expanding node 10
# Plan found!
# Expanding node 8 1
# Plan found!
# Expanding node 9 1
# Plan found!
# Expanding node 8 1
# Plan found!
# .. final duration: 0.028258085250854492 with num steps 9 and success=True.
# Running test problem 3
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 10 1
# Plan found!
# Expanding node 8e 1
# Plan found!
# .. final duration: 0.03037405014038086 with num steps 11 and success=True.
# Running test problem 4
# Expanding node 10
# Plan found!
# . final duration: 0.007769107818603516 with num steps 2 and success=True.
# Running test problem 5
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# .... final duration: 0.015248775482177734 with num steps 7 and success=True.
# Running test problem 0
# Expanding node 10
# Plan found!
# Expanding node 8 1
# Plan found!
# .. final duration: 0.013106107711791992 with num steps 5 and success=True.
# Running test problem 1
# Expanding node 81
# Plan found!
# . final duration: 0.006311178207397461 with num steps 2 and success=True.
# Running test problem 2
# Expanding node 81
# Plan found!
# Expanding node 10
# Plan found!
# Expanding node 8e 1
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 8de 1
# Plan found!
# .. final duration: 0.03112006187438965 with num steps 13 and success=True.
# Running test problem 3
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 4 1
# Plan found!
#  final duration: 0.01630401611328125 with num steps 5 and success=True.
# Running test problem 4
# Expanding node 10
# Plan found!
# Expanding node 8 1
# Plan found!
# Expanding node 7 1
# Plan found!
# . final duration: 0.015856027603149414 with num steps 6 and success=True.
# Running test problem 5
# Expanding node 10
# Plan found!
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# ... final duration: 0.022296905517578125 with num steps 7 and success=True.
# Running test problem 0
# Expanding node 10
# Plan found!
# Expanding node 10
# Plan found!
# ... final duration: 0.011919736862182617 with num steps 5 and success=True.
# Running test problem 1
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 5e 1
# Plan found!
#  final duration: 0.017822980880737305 with num steps 6 and success=True.
# Running test problem 2
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# Expanding node 4 1
# Plan found!
#  final duration: 0.01892828941345215 with num steps 5 and success=True.
# Running test problem 3
# Expanding node 10
# Plan found!
# Expanding node 81
# Plan found!
# . final duration: 0.01099395751953125 with num steps 3 and success=True.
# Running test problem 4
# Expanding node 10
# Plan found!
# Expanding node 101
# Plan found!
# ... final duration: 0.01567983627319336 with num steps 6 and success=True.
# Running test problem 5
# Expanding node 81
# Plan found!
# Expanding node 81
# Plan found!
# Expanding node 81
# Plan found!
# Expanding node 7 1
# Plan found!
# Expanding node 81
# Plan found!
# . final duration: 0.02459716796875 with num steps 7 and success=True.
# Running test problem 0
# ... final duration: 0.3987467288970947 with num steps 3 and success=True.
# Running test problem 1
# .. final duration: 0.22139191627502441 with num steps 2 and success=True.
# Running test problem 2
# ... final duration: 0.3413529396057129 with num steps 3 and success=True.
# Running test problem 3
# ......... final duration: 1.2243561744689941 with num steps 9 and success=True.
# Running test problem 4
# ...... final duration: 0.8514800071716309 with num steps 6 and success=True.
# Running test problem 5
# ..... final duration: 0.6888058185577393 with num steps 5 and success=True.
# Running test problem 0
# ... final duration: 0.32988691329956055 with num steps 3 and success=True.
# Running test problem 1
# ........ final duration: 1.277472972869873 with num steps 8 and success=True.
# Running test problem 2
# ........... final duration: 1.6584398746490479 with num steps 11 and success=True.
# Running test problem 3
# ....... final duration: 0.9887549877166748 with num steps 7 and success=True.
# Running test problem 4
# .. final duration: 0.18930411338806152 with num steps 2 and success=True.
# Running test problem 5
# ..... final duration: 0.6362550258636475 with num steps 5 and success=True.
# Running test problem 0
# ... final duration: 0.32892608642578125 with num steps 3 and success=True.
# Running test problem 1
# ........ final duration: 1.1471290588378906 with num steps 8 and success=True.
# Running test problem 2
# ......... final duration: 1.2139298915863037 with num steps 9 and success=True.
# Running test problem 3
# ......... final duration: 1.305283784866333 with num steps 9 and success=True.
# Running test problem 4
# ...... final duration: 0.8698487281799316 with num steps 6 and success=True.
# Running test problem 5
# ......... final duration: 1.2426178455352783 with num steps 9 and success=True.
# Running test problem 0
# ...... final duration: 0.9023120403289795 with num steps 6 and success=True.
# Running test problem 1
# ........ final duration: 1.1934080123901367 with num steps 8 and success=True.
# Running test problem 2
# ..... final duration: 0.7535121440887451 with num steps 5 and success=True.
# Running test problem 3
# ... final duration: 0.3776438236236572 with num steps 3 and success=True.
# Running test problem 4
# ........ final duration: 1.1710779666900635 with num steps 8 and success=True.
# Running test problem 5
# ......... final duration: 1.4094278812408447 with num steps 9 and success=True.
# Running test problem 0
# ..... final duration: 0.7038068771362305 with num steps 5 and success=True.
# Running test problem 1
# ...... final duration: 0.8244132995605469 with num steps 6 and success=True.
# Running test problem 2
# ... final duration: 0.31194496154785156 with num steps 3 and success=True.
# Running test problem 3
# ......... final duration: 1.459989070892334 with num steps 9 and success=True.
# Running test problem 4
# .. final duration: 0.2078237533569336 with num steps 2 and success=True.
# Running test problem 5
# ..... final duration: 0.6595780849456787 with num steps 5 and success=True.
# Running test problem 0
# ... final duration: 0.33853626251220703 with num steps 3 and success=True.
# Running test problem 1
# .... final duration: 0.5200750827789307 with num steps 4 and success=True.
# Running test problem 2
# ..... final duration: 0.7569050788879395 with num steps 5 and success=True.
# Running test problem 3
# ........ final duration: 1.2576828002929688 with num steps 8 and success=True.
# Running test problem 4
# .. final duration: 0.18656420707702637 with num steps 2 and success=True.
# Running test problem 5
# .......... final duration: 1.5538041591644287 with num steps 10 and success=True.
# Running test problem 0
# ........ final duration: 1.172572135925293 with num steps 8 and success=True.
# Running test problem 1
# .. final duration: 0.19517016410827637 with num steps 2 and success=True.
# Running test problem 2
# ..... final duration: 0.6190862655639648 with num steps 5 and success=True.
# Running test problem 3
# ..... final duration: 0.6750988960266113 with num steps 5 and success=True.
# Running test problem 4
# .. final duration: 0.18958783149719238 with num steps 2 and success=True.
# Running test problem 5
# .......... final duration: 1.3544070720672607 with num steps 10 and success=True.
# Running test problem 0
# ... final duration: 0.337414026260376 with num steps 3 and success=True.
# Running test problem 1
# .... final duration: 0.5158810615539551 with num steps 4 and success=True.
# Running test problem 2
# ... final duration: 0.35826683044433594 with num steps 3 and success=True.
# Running test problem 3
# ........ final duration: 1.2640748023986816 with num steps 8 and success=True.
# Running test problem 4
# .. final duration: 0.20112895965576172 with num steps 2 and success=True.
# Running test problem 5
# ......... final duration: 1.2492289543151855 with num steps 9 and success=True.
# Running test problem 0
# ......... final duration: 1.247849941253662 with num steps 9 and success=True.
# Running test problem 1
# .... final duration: 0.4846220016479492 with num steps 4 and success=True.
# Running test problem 2
# ..... final duration: 0.6951339244842529 with num steps 5 and success=True.
# Running test problem 3
# ... final duration: 0.3149440288543701 with num steps 3 and success=True.
# Running test problem 4
# ...... final duration: 0.8394219875335693 with num steps 6 and success=True.
# Running test problem 5
# .......... final duration: 1.3738689422607422 with num steps 10 and success=True.
# Running test problem 0
# ........ final duration: 1.1406989097595215 with num steps 8 and success=True.
# Running test problem 1
# .. final duration: 0.17758989334106445 with num steps 2 and success=True.
# Running test problem 2
# ..... final duration: 0.723524808883667 with num steps 5 and success=True.
# Running test problem 3
# ..... final duration: 0.674515962600708 with num steps 5 and success=True.
# Running test problem 4
# .. final duration: 0.20303988456726074 with num steps 2 and success=True.
# Running test problem 5
# ..... final duration: 0.654649019241333 with num steps 5 and success=True.
#
# ### SmallPOSARRadius0 ###
# Approach                             Duration    Expansions    Num Steps    Successes
# ---------------------------------  ----------  ------------  -----------  -----------
# depth_first_and_or_search           1.31549       2409           9           1
# iterative_deepening_and_or_search   1.09578      41137           5.33333     1
# pouct                               0.769404     14643.6         5.56667     1
# random                              0.0466338        0          49.1167      0.933333
# single_state_determinization        0.018757        25.3333      6.33333     1
# Running test problem 0
# .................................................................................................... final duration: 0.0868227481842041 with num steps 100 and success=False.
# Running test problem 1
# .................................................................................................... final duration: 0.0907888412475586 with num steps 100 and success=False.
# Running test problem 2
# .................................................................................................... final duration: 0.10659980773925781 with num steps 100 and success=False.
# Running test problem 3
# .................................................................................................... final duration: 0.10958480834960938 with num steps 100 and success=False.
# Running test problem 0
# .................................................................................................... final duration: 0.1156468391418457 with num steps 100 and success=False.
# Running test problem 1
# .................................................................................................... final duration: 0.11218976974487305 with num steps 100 and success=False.
# Running test problem 2
# .................................................................................................... final duration: 0.09792590141296387 with num steps 100 and success=False.
# Running test problem 3
# .................................................................................................... final duration: 0.1270751953125 with num steps 100 and success=False.
# Running test problem 0
# .................................................................................................... final duration: 0.1192619800567627 with num steps 100 and success=False.
# Running test problem 1
# .................................................................................................... final duration: 0.11852598190307617 with num steps 100 and success=False.
# Running test problem 2
# .................................................................................................... final duration: 0.11739993095397949 with num steps 100 and success=False.
# Running test problem 3
# .................................................................................................... final duration: 0.12310194969177246 with num steps 100 and success=False.
# Running test problem 0
# .................................................................................................... final duration: 0.11930704116821289 with num steps 100 and success=False.
# Running test problem 1
# .................................................................................................... final duration: 0.12253999710083008 with num steps 100 and success=False.
# Running test problem 2
# .................................................................................................... final duration: 0.12891268730163574 with num steps 100 and success=False.
# Running test problem 3
# .................................................................................................... final duration: 0.12338376045227051 with num steps 100 and success=False.
# Running test problem 0
# .................................................................................................... final duration: 0.13968205451965332 with num steps 100 and success=False.
# Running test problem 1
# .................................................................................................... final duration: 0.12126374244689941 with num steps 100 and success=False.
# Running test problem 2
# .................................................................................................... final duration: 0.12676000595092773 with num steps 100 and success=False.
# Running test problem 3
# .................................................................................................... final duration: 0.1201777458190918 with num steps 100 and success=False.
# Running test problem 0
# .................................................................................................... final duration: 0.12098932266235352 with num steps 100 and success=False.
# Running test problem 1
# .................................................................................................... final duration: 0.13019490242004395 with num steps 100 and success=False.
# Running test problem 2
# .................................................................................................... final duration: 0.13367390632629395 with num steps 100 and success=False.
# Running test problem 3
# .................................................................................................... final duration: 0.130845308303833 with num steps 100 and success=False.
# Running test problem 0
# ........................................................................... final duration: 0.09475994110107422 with num steps 75 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 0.13369274139404297 with num steps 100 and success=False.
# Running test problem 2
# .................................................................................................... final duration: 0.1360793113708496 with num steps 100 and success=False.
# Running test problem 3
# .................................................................................................... final duration: 0.12911319732666016 with num steps 100 and success=False.
# Running test problem 0
# .................................................................................................... final duration: 0.12362813949584961 with num steps 100 and success=False.
# Running test problem 1
# .................................................................................................... final duration: 0.1086878776550293 with num steps 100 and success=False.
# Running test problem 2
# .................................................................................................... final duration: 0.10058903694152832 with num steps 100 and success=False.
# Running test problem 3
# .................................................................................................... final duration: 0.10897207260131836 with num steps 100 and success=False.
# Running test problem 0
# .................................................................................................... final duration: 0.12459301948547363 with num steps 100 and success=False.
# Running test problem 1
# .................................................................................................... final duration: 0.12407493591308594 with num steps 100 and success=False.
# Running test problem 2
# .................................................................................................... final duration: 0.12312483787536621 with num steps 100 and success=False.
# Running test problem 3
# .................................................................................................... final duration: 0.12479376792907715 with num steps 100 and success=False.
# Running test problem 0
# .................................................................................................... final duration: 0.1287829875946045 with num steps 100 and success=False.
# Running test problem 1
# .................................................................................................... final duration: 0.12366604804992676 with num steps 100 and success=False.
# Running test problem 2
# .................................................................................................... final duration: 0.12793397903442383 with num steps 100 and success=False.
# Running test problem 3
# .................................................................................................... final duration: 0.12677812576293945 with num steps 100 and success=False.
# Running test problem 0
# .xpanding AND node 1685..............
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# .xpanding AND node 1685.............................. final duration: 0.8874678611755371 with num steps 32 and success=True.
# Running test problem 2
# .xpanding AND node 1685........ final duration: 0.8920021057128906 with num steps 10 and success=True.
# Running test problem 3
# Expanding AND node 1659Expanding AND node 1345
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Running iterative deepening with depth 26
# ......................... final duration: 2.780958890914917 with num steps 26 and success=True.
# Running test problem 2
# Running iterative deepening with depth 26
# ......... final duration: 2.7465338706970215 with num steps 10 and success=True.
# Running test problem 3
# Running iterative deepening with depth 26
# .... final duration: 2.8203237056732178 with num steps 5 and success=True.
# Running test problem 0
# Expanding node 26
# Plan found!
# ..... final duration: 0.023543119430541992 with num steps 6 and success=True.
# Running test problem 1
# Expanding node 19
# Plan found!
# Expanding node 38 1
# Plan found!
# ................ final duration: 0.04349708557128906 with num steps 20 and success=True.
# Running test problem 2
# Expanding node 26
# Plan found!
# Expanding node 23e 1
# Plan found!
# ..... final duration: 0.03894996643066406 with num steps 10 and success=True.
# Running test problem 3
# Expanding node 19
# Plan found!
# .... final duration: 0.016460895538330078 with num steps 5 and success=True.
# Running test problem 0
# Expanding node 38
# Plan found!
# Expanding node 32ding node 1
# Plan found!
# ............... final duration: 0.05876612663269043 with num steps 28 and success=True.
# Running test problem 1
# Expanding node 26
# Plan found!
# Expanding node 23e 1
# Plan found!
# Expanding node 15e 1
# Plan found!
# Expanding node 38 1
# Plan found!
# ................ final duration: 0.07848978042602539 with num steps 28 and success=True.
# Running test problem 2
# Expanding node 38
# Plan found!
# Expanding node 32ding node 1
# Plan found!
# Expanding node 23anding node 1
# Plan found!
# ..... final duration: 0.0683131217956543 with num steps 32 and success=True.
# Running test problem 3
# Expanding node 38
# Plan found!
# Expanding node 32ding node 1
# Plan found!
# Expanding node 30anding node 1
# Plan found!
# ........ final duration: 0.07413077354431152 with num steps 35 and success=True.
# Running test problem 0
# Expanding node 26
# Plan found!
# ..... final duration: 0.014808893203735352 with num steps 6 and success=True.
# Running test problem 1
# Expanding node 19
# Plan found!
# Expanding node 38 1
# Plan found!
# ................ final duration: 0.0518488883972168 with num steps 20 and success=True.
# Running test problem 2
# Expanding node 26
# Plan found!
# Expanding node 30e 1
# Plan found!
# Expanding node 15node 1
# Plan found!
# .... final duration: 0.06273174285888672 with num steps 16 and success=True.
# Running test problem 3
# Expanding node 30
# Plan found!
# Expanding node 7e 1
# Plan found!
# . final duration: 0.028783798217773438 with num steps 5 and success=True.
# Running test problem 0
# Expanding node 30
# Plan found!
# Expanding node 21ode 1
# Plan found!
# ..... final duration: 0.037420034408569336 with num steps 12 and success=True.
# Running test problem 1
# Expanding node 38
# Plan found!
# ............. final duration: 0.028169870376586914 with num steps 14 and success=True.
# Running test problem 2
# Expanding node 19
# Plan found!
# Expanding node 27 1
# Plan found!
# Expanding node 8e 1
# Plan found!
# . final duration: 0.03635001182556152 with num steps 8 and success=True.
# Running test problem 3
# Expanding node 26
# Plan found!
# Expanding node 38e 1
# Plan found!
# Expanding node 37anding node 1
# Plan found!
# ................ final duration: 0.09328794479370117 with num steps 35 and success=True.
# Running test problem 0
# Expanding node 30
# Plan found!
# Expanding node 21ode 1
# Plan found!
# ..... final duration: 0.046462059020996094 with num steps 12 and success=True.
# Running test problem 1
# Expanding node 19
# Plan found!
# Expanding node 38 1
# Plan found!
# ................ final duration: 0.05649590492248535 with num steps 20 and success=True.
# Running test problem 2
# Expanding node 38
# Plan found!
# Expanding node 32ding node 1
# Plan found!
# Expanding node 30anding node 1
# Plan found!
# Expanding node 15node 1
# Plan found!
# .... final duration: 0.09070205688476562 with num steps 38 and success=True.
# Running test problem 3
# Expanding node 26
# Plan found!
# Expanding node 30e 1
# Plan found!
# ........ final duration: 0.04342508316040039 with num steps 13 and success=True.
# Running test problem 0
# Expanding node 19
# Plan found!
# Expanding node 15 1
# Plan found!
# Expanding node 38 1
# Plan found!
# Expanding node 32xpanding node 1
# Plan found!
# ............... final duration: 0.08256411552429199 with num steps 38 and success=True.
# Running test problem 1
# Expanding node 38
# Plan found!
# ............. final duration: 0.030277013778686523 with num steps 14 and success=True.
# Running test problem 2
# Expanding node 30
# Plan found!
# ....... final duration: 0.022302865982055664 with num steps 8 and success=True.
# Running test problem 3
# Expanding node 30
# Plan found!
# Expanding node 7e 1
# Plan found!
# . final duration: 0.023991107940673828 with num steps 5 and success=True.
# Running test problem 0
# Expanding node 30
# Plan found!
# Expanding node 38ode 1
# Plan found!
# Expanding node 32xpanding node 1
# Plan found!
# ............... final duration: 0.07601094245910645 with num steps 38 and success=True.
# Running test problem 1
# Expanding node 19
# Plan found!
# Expanding node 27 1
# Plan found!
# Expanding node 38node 1
# Plan found!
# ............... final duration: 0.05965900421142578 with num steps 26 and success=True.
# Running test problem 2
# Expanding node 30
# Plan found!
# ....... final duration: 0.01835799217224121 with num steps 8 and success=True.
# Running test problem 3
# Expanding node 38
# Plan found!
# Expanding node 37ding node 1
# Plan found!
# ................ final duration: 0.0611269474029541 with num steps 29 and success=True.
# Running test problem 0
# Expanding node 19
# Plan found!
# Expanding node 27 1
# Plan found!
# ........ final duration: 0.033460140228271484 with num steps 12 and success=True.
# Running test problem 1
# Expanding node 38
# Plan found!
# ............. final duration: 0.028053998947143555 with num steps 14 and success=True.
# Running test problem 2
# Expanding node 30
# Plan found!
# ....... final duration: 0.019520998001098633 with num steps 8 and success=True.
# Running test problem 3
# Expanding node 19
# Plan found!
# .... final duration: 0.015177011489868164 with num steps 5 and success=True.
# Running test problem 0
# Expanding node 19
# Plan found!
# Expanding node 27 1
# Plan found!
# ........ final duration: 0.03356623649597168 with num steps 12 and success=True.
# Running test problem 1
# Expanding node 38
# Plan found!
# ............. final duration: 0.028676986694335938 with num steps 14 and success=True.
# Running test problem 2
# Expanding node 38
# Plan found!
# Expanding node 38ding node 1
# Plan found!
# ................. final duration: 0.059748172760009766 with num steps 30 and success=True.
# Running test problem 3
# Expanding node 30
# Plan found!
# Expanding node 7e 1
# Plan found!
# . final duration: 0.019714832305908203 with num steps 5 and success=True.
# Running test problem 0
# Expanding node 30
# Plan found!
# Expanding node 21ode 1
# Plan found!
# ....
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ........................................... final duration: 13.67352819442749 with num steps 48 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 24.029824018478394 with num steps 100 and success=False.
# Running test problem 2
# ............... final duration: 4.514878988265991 with num steps 15 and success=True.
# Running test problem 3
# .............. final duration: 4.58942985534668 with num steps 14 and success=True.
# Running test problem 0
# ............................. final duration: 7.706682920455933 with num steps 29 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 28.503970861434937 with num steps 100 and success=False.
# Running test problem 2
# .......... final duration: 2.683314085006714 with num steps 10 and success=True.
# Running test problem 3
# ...... final duration: 1.5859768390655518 with num steps 6 and success=True.
# Running test problem 0
# ...... final duration: 1.5734074115753174 with num steps 6 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 22.28024983406067 with num steps 100 and success=False.
# Running test problem 2
# ............. final duration: 3.6686010360717773 with num steps 13 and success=True.
# Running test problem 3
# ....... final duration: 1.8945698738098145 with num steps 7 and success=True.
# Running test problem 0
# ................... final duration: 4.715529918670654 with num steps 19 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 23.14520788192749 with num steps 100 and success=False.
# Running test problem 2
# .......... final duration: 2.4220762252807617 with num steps 10 and success=True.
# Running test problem 3
# ....... final duration: 1.7445859909057617 with num steps 7 and success=True.
# Running test problem 0
# ........................ final duration: 6.296290159225464 with num steps 24 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 22.01367998123169 with num steps 100 and success=False.
# Running test problem 2
# .......... final duration: 2.7135510444641113 with num steps 10 and success=True.
# Running test problem 3
# ....................... final duration: 5.86885404586792 with num steps 23 and success=True.
# Running test problem 0
# .............. final duration: 4.561264276504517 with num steps 14 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 24.205720901489258 with num steps 100 and success=False.
# Running test problem 2
# .......... final duration: 2.3224780559539795 with num steps 10 and success=True.
# Running test problem 3
# ................... final duration: 5.217172384262085 with num steps 19 and success=True.
# Running test problem 0
# ................................ final duration: 8.381268978118896 with num steps 32 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 24.68863797187805 with num steps 100 and success=False.
# Running test problem 2
# ......... final duration: 2.136894941329956 with num steps 9 and success=True.
# Running test problem 3
# ......... final duration: 2.584467887878418 with num steps 9 and success=True.
# Running test problem 0
# ...
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# .xpanding AND node 1668................................... final duration: 0.8359487056732178 with num steps 37 and success=True.
# Running test problem 1
# Expanding AND node 1646
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Running iterative deepening with depth 15
# ............ final duration: 2.0368199348449707 with num steps 13 and success=True.
# Running test problem 1
# Running iterative deepening with depth 15
# .............. final duration: 1.8553190231323242 with num steps 15 and success=True.
# Running test problem 2
# Running iterative deepening with depth 15
# .............. final duration: 1.7933979034423828 with num steps 15 and success=True.
# Running test problem 3
# Running iterative deepening with depth 15
# ............. final duration: 1.819720983505249 with num steps 14 and success=True.
# Running test problem 0
# Expanding node 44
# Plan found!
# ..... final duration: 0.0227510929107666 with num steps 6 and success=True.
# Running test problem 1
# Expanding node 31
# Plan found!
# Expanding node 73e 1
# Plan found!
# ................. final duration: 0.06252598762512207 with num steps 22 and success=True.
# Running test problem 2
# Expanding node 44
# Plan found!
# Expanding node 38de 1
# Plan found!
# ...... final duration: 0.044223785400390625 with num steps 12 and success=True.
# Running test problem 3
# Expanding node 31
# Plan found!
# .... final duration: 0.013887166976928711 with num steps 5 and success=True.
# Running test problem 0
# Expanding node 73
# Plan found!
# Expanding node 59nding node 1
# Plan found!
# ................ final duration: 0.08222532272338867 with num steps 30 and success=True.
# Running test problem 1
# Expanding node 44
# Plan found!
# Expanding node 38de 1
# Plan found!
# Expanding node 25ode 1
# Plan found!
# Expanding node 73de 1
# Plan found!
# ................. final duration: 0.09997987747192383 with num steps 34 and success=True.
# Running test problem 2
# Expanding node 73
# Plan found!
# Expanding node 59nding node 1
# Plan found!
# Expanding node 38xpanding node 1
# Plan found!
# ...... final duration: 0.09644508361816406 with num steps 36 and success=True.
# Running test problem 3
# Expanding node 73
# Plan found!
# Expanding node 59nding node 1
# Plan found!
# Expanding node 57xpanding node 1
# Plan found!
# ......... final duration: 0.10462498664855957 with num steps 39 and success=True.
# Running test problem 0
# Expanding node 44
# Plan found!
# ..... final duration: 0.01972508430480957 with num steps 6 and success=True.
# Running test problem 1
# Expanding node 31
# Plan found!
# Expanding node 73e 1
# Plan found!
# ................. final duration: 0.06119704246520996 with num steps 22 and success=True.
# Running test problem 2
# Expanding node 44
# Plan found!
# Expanding node 57de 1
# Plan found!
# Expanding node 26g node 1
# Plan found!
# ..... final duration: 0.06878376007080078 with num steps 20 and success=True.
# Running test problem 3
# Expanding node 57
# Plan found!
# Expanding node 36node 1
# Plan found!
# Expanding node 57ode 1
# Plan found!
# ......... final duration: 0.0819997787475586 with num steps 23 and success=True.
# Running test problem 0
# Expanding node 57
# Plan found!
# Expanding node 36node 1
# Plan found!
# ...... final duration: 0.05458998680114746 with num steps 14 and success=True.
# Running test problem 1
# Expanding node 73
# Plan found!
# ............. final duration: 0.0434267520904541 with num steps 14 and success=True.
# Running test problem 2
# Expanding node 31
# Plan found!
# Expanding node 49e 1
# Plan found!
# Expanding node 73g node 1
# Plan found!
# Expanding node 73xpanding node 1
# Plan found!
# .................. final duration: 0.13204193115234375 with num steps 48 and success=True.
# Running test problem 3
# Expanding node 44
# Plan found!
# Expanding node 38de 1
# Plan found!
# Expanding node 25ode 1
# Plan found!
# ..... final duration: 0.05795693397521973 with num steps 17 and success=True.
# Running test problem 0
# Expanding node 57
# Plan found!
# Expanding node 25node 1
# Plan found!
# Expanding node 73de 1
# Plan found!
# Expanding node 59Expanding node 1
# Plan found!
# ................ final duration: 0.1311359405517578 with num steps 46 and success=True.
# Running test problem 1
# Expanding node 73
# Plan found!
# ............. final duration: 0.046198129653930664 with num steps 14 and success=True.
# Running test problem 2
# Expanding node 73
# Plan found!
# Expanding node 59nding node 1
# Plan found!
# Expanding node 44xpanding node 1
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Expanding node 57
# Plan found!
# ......... final duration: 0.056221961975097656 with num steps 15 and success=True.
# Running test problem 0
# Expanding node 31
# Plan found!
# Expanding node 49e 1
# Plan found!
# ......... final duration: 0.05623888969421387 with num steps 14 and success=True.
# Running test problem 1
# Expanding node 73
# Plan found!
# ............. final duration: 0.03533005714416504 with num steps 14 and success=True.
# Running test problem 2
# Expanding node 57
# Plan found!
# ....... final duration: 0.04239010810852051 with num steps 8 and success=True.
# Running test problem 3
# Expanding node 31
# Plan found!
# .... final duration: 0.01730203628540039 with num steps 5 and success=True.
# Running test problem 0
# Expanding node 31
# Plan found!
# Expanding node 49e 1
# Plan found!
# ......... final duration: 0.037713050842285156 with num steps 14 and success=True.
# Running test problem 1
# Expanding node 73
# Plan found!
# ............. final duration: 0.053092002868652344 with num steps 14 and success=True.
# Running test problem 2
# Expanding node 73
# Plan found!
# Expanding node 73nding node 1
# Plan found!
# .................. final duration: 0.0909581184387207 with num steps 32 and success=True.
# Running test problem 3
# Expanding node 57
# Plan found!
# Expanding node 36node 1
# Plan found!
# Expanding node 57ode 1
# Plan found!
# ......... final duration: 0.07525992393493652 with num steps 23 and success=True.
# Running test problem 0
# Expanding node 57
# Plan found!
# Expanding node 36node 1
# Plan found!
# ...... final duration: 0.05970621109008789 with num steps 14 and success=True.
# Running test problem 1
# Expanding node 57
# Plan found!
# Expanding node 73node 1
# Plan found!
# .................. final duration: 0.0739901065826416 with num steps 26 and success=True.
# Running test problem 2
# Expanding node 57
# Plan found!
# ....... final duration: 0.029310941696166992 with num steps 8 and success=True.
# Running test problem 3
# Expanding node 44
# Plan found!
# Expanding node 57de 1
# Plan found!
# ......... final duration: 0.0642082691192627 with num steps 15 and success=True.
# Running test problem 0
# .............................................. final duration: 8.603543996810913 with num steps 46 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 21.54203987121582 with num steps 100 and success=False.
# Running test problem 2
# ................. final duration: 2.850781202316284 with num steps 17 and success=True.
# Running test problem 3
# ..... final duration: 0.7086918354034424 with num steps 5 and success=True.
# Running test problem 0
# ............ final duration: 1.98164701461792 with num steps 12 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 22.932295322418213 with num steps 100 and success=False.
# Running test problem 2
# ........... final duration: 1.6704440116882324 with num steps 11 and success=True.
# Running test problem 3
# ...... final duration: 0.96378493309021 with num steps 6 and success=True.
# Running test problem 0
# ......... final duration: 1.3055338859558105 with num steps 9 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 22.651807069778442 with num steps 100 and success=False.
# Running test problem 2
# ............ final duration: 1.8352289199829102 with num steps 12 and success=True.
# Running test problem 3
# ....... final duration: 0.9252669811248779 with num steps 7 and success=True.
# Running test problem 0
# ............... final duration: 2.511582136154175 with num steps 15 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 21.868088722229004 with num steps 100 and success=False.
# Running test problem 2
# ................. final duration: 2.8085989952087402 with num steps 17 and success=True.
# Running test problem 3
# ...... final duration: 0.8065390586853027 with num steps 6 and success=True.
# Running test problem 0
# ....... final duration: 1.0408868789672852 with num steps 7 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 18.527104139328003 with num steps 100 and success=False.
# Running test problem 2
# ............ final duration: 1.810835838317871 with num steps 12 and success=True.
# Running test problem 3
# ..... final duration: 0.7629320621490479 with num steps 5 and success=True.
# Running test problem 0
# ......... final duration: 1.304581880569458 with num steps 9 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 18.466203927993774 with num steps 100 and success=False.
# Running test problem 2
# ............... final duration: 2.30679988861084 with num steps 15 and success=True.
# Running test problem 3
# ...... final duration: 0.7703080177307129 with num steps 6 and success=True.
# Running test problem 0
# ........ final duration: 1.151371955871582 with num steps 8 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 21.983870029449463 with num steps 100 and success=False.
# Running test problem 2
# ............. final duration: 1.9592511653900146 with num steps 13 and success=True.
# Running test problem 3
# ...... final duration: 0.8866522312164307 with num steps 6 and success=True.
# Running test problem 0
# ........ final duration: 1.1252589225769043 with num steps 8 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 22.254608869552612 with num steps 100 and success=False.
# Running test problem 2
# ............... final duration: 2.3481287956237793 with num steps 15 and success=True.
# Running test problem 3
# ....... final duration: 0.957665205001831 with num steps 7 and success=True.
# Running test problem 0
# ........ final duration: 1.1266539096832275 with num steps 8 and success=True.
# Running test problem 1
# .................................................................................................... final duration: 23.359288215637207 with num steps 100 and success=False.
# Running test problem 2
# .......... final duration: 1.4860782623291016 with num steps 10 and success=True.
# Running test problem 3
# .............................. final duration: 4.955097198486328 with num steps 30 and success=True.
# Running test problem 0
# .......... final duration: 1.4941439628601074 with num steps 10 and success=True.
# Running test problem 1
# .................................................. final duration: 9.256562948226929 with num steps 50 and success=True.
# Running test problem 2
# ......... final duration: 1.2675459384918213 with num steps 9 and success=True.
# Running test problem 3
# ...... final duration: 0.8439509868621826 with num steps 6 and success=True.
#
# ### POSARRadius0Xray ###
# Approach                             Duration    Expansions    Num Steps    Successes
# ---------------------------------  ----------  ------------  -----------  -----------
# depth_first_and_or_search           0.873349        1668          36.75         1
# iterative_deepening_and_or_search   1.87631       160574          14.25         1
# pouct                               6.43529       154448          32.425        0.775
# random                              0.0475166          0          96.425        0.075
# single_state_determinization        0.0678123        115.15       21.45         1
#
# ********************************************************************************
#
# ### SmallPOSARRadius0 ###
# Approach                             Duration    Expansions    Num Steps    Successes
# ---------------------------------  ----------  ------------  -----------  -----------
# depth_first_and_or_search           1.31549       2409           9           1
# iterative_deepening_and_or_search   1.09578      41137           5.33333     1
# pouct                               0.769404     14643.6         5.56667     1
# random                              0.0466338        0          49.1167      0.933333
# single_state_determinization        0.018757        25.3333      6.33333     1
#
# ### POSARRadius1 ###
# Approach                             Duration    Expansions    Num Steps    Successes
# ---------------------------------  ----------  ------------  -----------  -----------
# depth_first_and_or_search           1.02204        1685           16.25         1
# iterative_deepening_and_or_search   2.87231      146169           13.25         1
# pouct                               9.09601      171527           36.25         0.75
# random                              0.119548          0           99.375        0.025
# single_state_determinization        0.0436026        56.575       17.15         1
#
# ### POSARRadius0 ###
# Approach                             Duration    Expansions    Num Steps    Successes
# ---------------------------------  ----------  ------------  -----------  -----------
# depth_first_and_or_search           2.39207        4408           43.25         1
# iterative_deepening_and_or_search  11.6149       541276           15.75         1
# pouct                               9.47066      172666           36.7          0.775
# random                              0.0562929         0           99.375        0.025
# single_state_determinization        0.0443446        62.825       21.45         1
#
# ### POSARRadius1Xray ###
# Approach                             Duration    Expansions    Num Steps    Successes
# ---------------------------------  ----------  ------------  -----------  -----------
# depth_first_and_or_search           1.12431        2255           33.25         1
# iterative_deepening_and_or_search   2.00979      177942           14.25         1
# pouct                               6.9171       168797           35.4          0.75
# random                              0.0611043         0           96.425        0.075
# single_state_determinization        0.068466        103.675       17.15         1
#
# ### POSARRadius0Xray ###
# Approach                             Duration    Expansions    Num Steps    Successes
# ---------------------------------  ----------  ------------  -----------  -----------
# depth_first_and_or_search           0.873349        1668          36.75         1
# iterative_deepening_and_or_search   1.87631       160574          14.25         1
# pouct                               6.43529       154448          32.425        0.775
# random                              0.0475166          0          96.425        0.075
# single_state_determinization        0.0678123        115.15       21.45         1
